# %%
import duckdb
con = duckdb.connect("data/gold.duckdb")

# %%
#con.sql("INSTALL ui;")
con.sql("LOAD ui;")
con.sql("CALL start_ui();")
# Out:
# ┌──────────────────────────────────────┐
# │                result                │
# │               varchar                │
# ├──────────────────────────────────────┤
# │ UI started at http://localhost:4213/ │
# └──────────────────────────────────────┘
